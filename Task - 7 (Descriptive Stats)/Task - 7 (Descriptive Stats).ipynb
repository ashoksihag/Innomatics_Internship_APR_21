# %% [markdown]
# # Mean
# The mean is the most widely spread measure of central tendency. It is the simple average of the dataset.
#
# Note: easily affected by outliers
#
# The formula to calculate the mean is: $$ \mu = \frac{1}{n} Σ_i^n x_i  = \frac{(x_1 + x_2 + x_3 + ...x_n)}{n} $$
#
# here,
#
# µ = mean
#
# n = total number of values
#
# $ x_i $ = data values

# %% [markdown]
# Example: To find the average of the four numbers 2, 4, 6, 8, we need to add the number first.
# 1. 2 + 4 + 6+ 8 = 20
# 2. Divide the sum by the total number of numbers, i.e  4.
# 3. 20/4 = 5 is the average or mean

# %% [markdown]
# # Median
# The median is the midpoint of the ordered dataset. It is not as popular as the mean, but is often used in academia and data science. That is since it is not affected by outliers.
#
# In an ordered dataset, the median is the number at position:
#
# when n is odd : $$ \frac{n+1}{2}    $$
# when n is even : $$ \frac{(\frac{n}{2}) + (\frac{n}{2} + 1)}{2}   $$

# %% [markdown]
# Example: If the given list is 4, 2, 8, 10, 19.
# 1. Arrange the numbers in ascending order i .e 2, 4, 8, 10, 19.
# 2. As the total numbers are 5, so the middle number 8 is the median here.

# %% [markdown]
# # Mode
#
# The mode is the value that occurs most often. A dataset can have 0 modes, 1 mode or multiple modes.
#
# The mode is calculated simply by finding the value with the highest frequency.

# %% [markdown]
# Example: In the given series 3,3,5,6,7,7,8,1,1,1,4,5,6
# 1. Find the frequency of each number.
# 2. For number 3 it’s 2, for 5 it’s 2, for 6 it’s 2, for 7 it’s 2, for 8 it’s one, for 1 it’s 3, for 4 it’s 1.
# 3. The number with the highest frequency is the mode.

# %%
#mean, median & mode user defined formula

def µ(x):
    sum=0
    for i in x:
        sum+=i
    mean=sum/len(x)
    return mean

def Med(x):
    n=len(x)
    sorted(x)
    if len(x)%2==0:
        return (x[n/2]+x[n/2 -1])/2
    else:
        return x[(n+1)/2]
from collections import Counter    
def Mod(x):
    c = Counter(x)
    return [i for i,value in c.items() if value==c.most_common(1)[0][1]]

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('data.csv')

# %%
df.columns
# Out:
# Index(['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members',
#        'Emi_or_Rent_Amt', 'Annual_HH_Income', 'Highest_Qualified_Member',
#        'No_of_Earning_Members'],
#       dtype='object')

# %%
#find mean using defined function
µ(df['Mthly_HH_Income'])
# Out:
# 41558.0

# %%
#cross check with built in function
df['Mthly_HH_Income'].mean()
# Out:
# 41558.0

# %%
#find median using defined function
Med(df['Mthly_HH_Income'])
# Out:
# 35000.0

# %%
#cross check with built in function
df['Mthly_HH_Income'].median()
# Out:
# 35000.0

# %%
#find mode using defined function
Mod(df['Mthly_HH_Income'])
# Out:
# [45000]

# %%
#cross check with built in function
df['Mthly_HH_Income'].mode()
# Out:
# 0    45000
# dtype: int64

# %% [markdown]
# # Variance
# Variance measures the variability of the data around its mean. High variance means there is more variability
# or volatility whereas low variance indicates less variability. If the variance of a series is zero that means
# all the numbers of that series are the same.
#
# Population variance formula: $$ \sigma^2 =  \frac{Σ_i^n (x_i - µ)^2}{n} $$
# Sample variance formula: $$ s^2 =  \frac{Σ_i^n (x_i - µ)^2}{n-1} $$
#
# # Standard deviation:
# It is simply the square root of the variance and it is the parametric equivalent of the Interquartile range.
# This together with variance represents the variability in the data around the mean. This is also often termed as ‘volatility’.
#
# Population standard deviation: $$ \sigma = \sqrt\frac{Σ_i^n (x_i - µ)^2}{n} $$
# Sample standard deviation: $$ s = \sqrt\frac{Σ_i^n (x_i - µ)^2}{n-1} $$
#
# Example: If a die is rolled, then find the variance and standard deviation of the possibilities.
#
# When a die is rolled, the possible outcome will be 6. So the sample space, n = 6 and the data set = { 1;2;3;4;5;6}.
#
# To find the variance, first, we need to calculate the mean of the data set.
#
# Mean, µ = (1+2+3+4+5+6)/6 = 3.5
#
# We can put the value of data and mean in the formula to get;
#
# $$ \sigma^2 =  \frac{Σ_i^n (x_i - µ)^2}{n} $$
#
# $ σ^2 $=$ \frac{(6.25+2.25+0.25+0.25+2.25+6.25)}{6} $
#
# $ σ^2 $ = 2.917
#
# Now, the standard deviation,σ = √2.917 = 1.708

# %%
#Variance & standard deviation user defined formula

def Variance(x):
    m=µ(x)
    v=0
    for i in x:
        v+=(i-m)**2
    v=v/(len(x)-1)
    return v

def std_dev(x):
    m=µ(x)
    v=0
    for i in x:
        v+=(i-m)**2
    v=v/(len(x)-1)
    v=v**.5
    return v

# %%
#find variance using defined function
Variance(df['Mthly_HH_Income'])
# Out:
# 681100853.0612245

# %%
#cross check with built in function
df['Mthly_HH_Income'].var()
# Out:
# 681100853.0612245

# %%
#find standard deviation using defined function
std_dev(df['Mthly_HH_Income'])
# Out:
# 26097.908978713687

# %%
#cross check with built in function
df['Mthly_HH_Income'].std()
# Out:
# 26097.908978713687

# %% [markdown]
# # Correlation
# Correlation is a measure of the joint variability of two variables. Unlike covariance, correlation could be thought of as a
# standardized measure. It takes on values between -1 and 1, thus it is easy for us to interpret the result.
#
# ➢ A correlation of 1, known as perfect positive correlation, means that one variable is perfectly explained by the other.
#
# ➢ A correlation of 0 means that the variables are independent.
#
# ➢ A correlation of -1, known as perfect negative correlation, means that one variable is explaining the other one
# perfectly, but they move in opposite directions.
#
# $$ r = \frac{Σ_i^n (x_i - µ_x)(y_i - µ_y)}{\sqrt(Σ_i^n (x_i - µ_x)^2Σ_i^n(y_i - µ_y)^2)}$$

# %%
#Correlation user defined formula
def correlation(x, y):
    
    mean_x = sum(x)/float(len(x))
    mean_y = sum(y)/float(len(y))
    # Subtracting mean from the individual elements
    sub_x = [i-mean_x for i in x]
    sub_y = [i-mean_y for i in y]
    # covariance for x and y
    numerator = sum([sub_x[i]*sub_y[i] for i in range(len(sub_x))])
    # Standard Deviation of x and y
    std_deviation_x = sum([sub_x[i]**2.0 for i in range(len(sub_x))])
    std_deviation_y = sum([sub_y[i]**2.0 for i in range(len(sub_y))])
    # square root
    denominator = (std_deviation_x*std_deviation_y)**0.5 
    cor = numerator/denominator
    return cor

# %%
#find correlation using defined function
correlation(df['Mthly_HH_Income'],df['Mthly_HH_Expense'])
# Out:
# 0.6492152549316461

# %%
#cross check with built in function
df.corr()
# Out:
#                        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  \
# Mthly_HH_Income               1.000000          0.649215           0.448317
# Mthly_HH_Expense              0.649215          1.000000           0.639702
# No_of_Fly_Members             0.448317          0.639702           1.000000
# Emi_or_Rent_Amt               0.036976          0.405280           0.085808
# Annual_HH_Income              0.970315          0.591222           0.430868
# No_of_Earning_Members         0.347883          0.311915           0.597482
#
#                        Emi_or_Rent_Amt  Annual_HH_Income  \
# Mthly_HH_Income               0.036976          0.970315
# Mthly_HH_Expense              0.405280          0.591222
# No_of_Fly_Members             0.085808          0.430868
# Emi_or_Rent_Amt               1.000000          0.002716
# Annual_HH_Income              0.002716          1.000000
# No_of_Earning_Members        -0.097431          0.296679
#
# ...

# %% [markdown]
# # Normal Distribution or the ‘Bell’ Curve
# The Normal distribution is a very common continuous probability distribution, and is a very important concept in statistics.
# It is widely used in natural, econometrics and social sciences to represent real-valued random variables, whose distributions
# are not known.
# It is informally known as a bell curve since it resembles a bell in a two-dimensional space
#
# ![image.png](attachment:image.png)

# %% [markdown]
# If the probability density function looks as above, we say the variable follows a Normal distribution.
# The probability density function is given as below: $$ f(x) = \frac{1}{\sqrt(2πσ)}e^\frac{(x-µ)^2}{2σ^2}$$
# We write, X ~ N (μ, $σ^2$)

# %% [markdown]
# ## Characteristics of Normal Distribution
# The following properties of normal distribution make it the most preferred distribution in any kind of analysis.
#
# • Normal distribution is symmetric around it’s mean
#
# ![image.png](attachment:image.png)
#
# • The variable can take any real number between –∞ to +∞
#
# • Location is determined by μ and shape is determined by σ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# • Area covered around the mean with multiples of standard deviation is fixed, and this information is used widely across statistical analysis.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Shape Parameters in a Distribution – Skewness and Kurtosis
# “Skewness” measures the symmetricity of a distribution. For example, let’s look at the
# distribution of a normal distribution.
#
# ![image.png](attachment:image.png)
#
# The above graph is symmetric around the central blue line (the left side is a mirror image of the right side). This is called a symmetric distribution. The “skewness” measure for this distribution is zero (0). For any symmetric distribution, Mean = Median = Mode

# %% [markdown]
# Now, let’s look at the following graph.
#
# ![image.png](attachment:image.png)
#
# Clearly, it is not symmetric. Here Mean > Median > Mode. We can say that the distribution has a longer tail towards the higher values. Hence, for this kind of asymmetric distributions, skewness measure is positive, and they are called “Positively Skewed Distribution”
#
# Similarly, for negatively skewed distributions Mean < Median < Mode and they have a longer tail towards lower values.

# %% [markdown]
# Kurtosis is another measure of shape of a distribution which measures whether the distribution is
# “flatter” or “thinner” than a normal distribution with same mean and variance.
#
# ![image.png](attachment:image.png)

# %%
# Initiating a figure
plt.figure(figsize=(12, 8))

# Creating a plot with 1 row and 2 cols

plt.subplot(2, 3, 1)
sns.distplot(df['Mthly_HH_Income'])

plt.subplot(2, 3, 2)
sns.distplot(df['Mthly_HH_Expense'])

plt.subplot(2, 3, 3)
sns.distplot(df['Emi_or_Rent_Amt'])

plt.subplot(2, 3, 4)
sns.distplot(df['Annual_HH_Income'])

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %%
df['Emi_or_Rent_Amt'].skew()
# Out:
# 3.403679844103547

# %%
df['Emi_or_Rent_Amt'].kurt()
# Out:
# 14.202522820819258

# %% [markdown]
# # (Q-Q) plot:
# It shows the distribution of the data against the expected normal distribution. For normally distributed data, observations should lie approximately on a straight line. If the data is non-normal, the points form a curve that deviates markedly from a straight line. Possible outliers are points at the ends of the line, distance from the bulk of the observations.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Skewed Q-Q plots
# Q-Q plots are also used to find the Skewness (a measure of “asymmetry”) of a distribution. When we plot theoretical quantiles on the x-axis and the sample quantiles whose distribution we want to know on the y-axis then we see a very peculiar shape of a Normally distributed Q-Q plot for skewness. If the bottom end of the Q-Q plot deviates from the straight line but the upper end is not, then we can clearly say that the distribution has a longer tail to its left or simply it is left-skewed (or negatively skewed) but when we see the upper end of the Q-Q plot to deviate from the straight line and the lower and follows a straight line then the curve has a longer till to its right and it is right-skewed (or positively skewed).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Tailed Q-Q plots
# Similarly, we can talk about the Kurtosis (a measure of “Tailedness”) of the distribution by simply looking at its Q-Q plot. The distribution with a fat tail will have both the ends of the Q-Q plot to deviate from the straight line and its center follows a straight line, whereas a thin-tailed distribution will form a Q-Q plot with a very less or negligible deviation at the ends thus making it a perfect fit for the Normal Distribution.
#
# ![image.png](attachment:image.png)

# %%
#Implementation of Q-Q Plot
import scipy.stats as stats
import matplotlib.pyplot as plt
# %matplotlib inline

stats.probplot(df['Mthly_HH_Income'], dist='norm', plot=plt)
plt.title('Normal Q-Q Plot')
plt.grid()
plt.show()

# %%
stats.probplot(df['Mthly_HH_Expense'], dist='norm', plot=plt)
plt.title('Normal Q-Q Plot')
plt.grid()
plt.show()

# %% [markdown]
# # Box-Cox
# The Box-Cox transformation transforms our data so that it closely resembles a normal distribution. In many statistical techniques, we assume that the errors are normally distributed. This assumption allows us to construct confidence intervals and conduct hypothesis tests.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Implementation of Box-Cox Transformation

import seaborn as sns

sns.distplot(df['Mthly_HH_Income'])

# %%
# Normality Test

stats.probplot(df['Mthly_HH_Income'], dist="norm", plot=plt)

plt.grid()

# %%
# x_t = tranformed by box-cox, l = Lambda

x_t, l = stats.boxcox(df['Mthly_HH_Income'])

print(l)
# Out:
# 0.3031376789702236

# %%
stats.probplot(x_t, dist="norm", plot=plt)

plt.grid()
